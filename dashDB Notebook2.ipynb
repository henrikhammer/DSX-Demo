# %% [markdown]
# When you have setup a connection to the data source in your project, you can drag and drop the connection information into the cell below from the "Find and Add Data" palette to the right:
# There are various styles.
# Below we establish the connection using a SparkSession DataFrame
# As the schema use GOSALESDW
# As the table use EMP_EXPENSE_FACT
# Then click "Insert Code"

# %%
# The code was removed by DSX for sharing.
# Out:
# [Row(DAY_KEY=20120731, ORGANIZATION_KEY=11170, POSITION_KEY=43639, EMPLOYEE_KEY=4053, EXPENSE_TYPE_KEY=2124, ACCOUNT_KEY=8056, EXPENSE_UNIT_QUANTITY=0.03, EXPENSE_TOTAL=Decimal('483.97')),
#  Row(DAY_KEY=20120731, ORGANIZATION_KEY=11170, POSITION_KEY=43639, EMPLOYEE_KEY=4053, EXPENSE_TYPE_KEY=2130, ACCOUNT_KEY=8050, EXPENSE_UNIT_QUANTITY=0.005, EXPENSE_TOTAL=Decimal('11574.80')),
#  Row(DAY_KEY=20120731, ORGANIZATION_KEY=11170, POSITION_KEY=43639, EMPLOYEE_KEY=4053, EXPENSE_TYPE_KEY=2131, ACCOUNT_KEY=8049, EXPENSE_UNIT_QUANTITY=116.25, EXPENSE_TOTAL=Decimal('3364.01')),
#  Row(DAY_KEY=20120831, ORGANIZATION_KEY=11170, POSITION_KEY=43639, EMPLOYEE_KEY=4053, EXPENSE_TYPE_KEY=2104, ACCOUNT_KEY=8050, EXPENSE_UNIT_QUANTITY=7.5, EXPENSE_TOTAL=Decimal('198.16')),
#  Row(DAY_KEY=20120831, ORGANIZATION_KEY=11170, POSITION_KEY=43639, EMPLOYEE_KEY=4053, EXPENSE_TYPE_KEY=2120, ACCOUNT_KEY=8052, EXPENSE_UNIT_QUANTITY=0.08, EXPENSE_TOTAL=Decimal('872.64'))]

# %%
data_df_1.printSchema()
# Out:
# root
#  |-- DAY_KEY: integer (nullable = false)
#  |-- ORGANIZATION_KEY: integer (nullable = false)
#  |-- POSITION_KEY: integer (nullable = false)
#  |-- EMPLOYEE_KEY: integer (nullable = false)
#  |-- EXPENSE_TYPE_KEY: integer (nullable = false)
#  |-- ACCOUNT_KEY: integer (nullable = false)
#  |-- EXPENSE_UNIT_QUANTITY: double (nullable = true)
#  |-- EXPENSE_TOTAL: decimal(19,2) (nullable = true)

# %%
data_df_1.show()
# Out:
# +--------+----------------+------------+------------+----------------+-----------+---------------------+-------------+
# | DAY_KEY|ORGANIZATION_KEY|POSITION_KEY|EMPLOYEE_KEY|EXPENSE_TYPE_KEY|ACCOUNT_KEY|EXPENSE_UNIT_QUANTITY|EXPENSE_TOTAL|
# +--------+----------------+------------+------------+----------------+-----------+---------------------+-------------+
# |20130228|           11146|       43630|        4270|            2124|       8056|                 0.03|        66.64|
# |20130228|           11146|       43630|        4270|            2133|       8050|                 3.75|       100.00|
# |20130331|           11146|       43630|        4270|            2101|       8049|                150.0|      2245.45|
# |20130331|           11146|       43630|        4270|            2104|       8050|                 15.0|       224.54|
# |20130331|           11146|       43630|        4270|            2114|       8050|                 12.0|       252.00|
# ...

# %%
# Convert spark dataframe to pandas
import pandas as pd
data_df_1.toPandas()
#dashdbDF.toPandas()
# Out:
#          DAY_KEY  ORGANIZATION_KEY  POSITION_KEY  EMPLOYEE_KEY  \
# 0       20110531             11199         43606          4857
# 1       20110531             11199         43606          4857
# 2       20110531             11199         43606          4857
# 3       20110531             11199         43606          4857
# 4       20110630             11199         43606          4857
# 5       20110630             11199         43606          4857
# 6       20110630             11199         43606          4857
# 7       20110630             11199         43606          4857
# 8       20110630             11199         43606          4857
# 9       20110731             11199         43606          4857
# 10      20110731             11199         43606          4857
# 11      20110731             11199         43606          4857
# 12      20110731             11199         43606          4857
# 13      20110831             11199         43606          4857
# ...
